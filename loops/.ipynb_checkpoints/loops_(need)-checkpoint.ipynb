# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 The for iterator

# %% [markdown]
# ## 1.1 for with a list

# %%
operator_names=["Chong Yue", "Ling", "Shu", "Nian", "Dusk"]
for sibling in operator_names:
    print(f"{sibling} is a Sui sibling.")

prime_numbers=[2,3,5,7,11,13,17,19]
import numpy as np
prime_array=np.array(prime_numbers)
for prime in prime_array:
    print(f"{prime} is a prime number.")
# Out:
# Chong Yue is a Sui sibling.
# Ling is a Sui sibling.
# Shu is a Sui sibling.
# Nian is a Sui sibling.
# Dusk is a Sui sibling.
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.

# %% [markdown]
# `for` is one of the ways to do loops in Python
# - `for xx in list` assigns `xx` to each element in the list/array (works with numbers and strings)
# - it then runs the code block (marked out by `:` and indent) for each element
#     - check indents if not working as intended
# - change `xx` to something that can represent the list elements for clarity (can name it anything as long as it's consistent with the rest of the code)
# - `for` loop is repeated for each element in the list/array
#
# seems slightly slower for arrays...

# %% [markdown]
# ## 1.2 for with enumerate

# %%
siblings=(["Chong Yue", "Ling", "Shu", "Nian", "Dusk"])
birthdays=["1/1","3/3","6/6","9/9","11/11"]
for count, name in enumerate(siblings, 1):
    print(f"{count}: {name} is a Sui sibling.")
# Out:
# 1: Chong Yue is a Sui sibling.
# 2: Ling is a Sui sibling.
# 3: Shu is a Sui sibling.
# 4: Nian is a Sui sibling.
# 5: Dusk is a Sui sibling.

# %%
print(count)
for count in enumerate(siblings,1):
    print(count)
# Out:
# 5
# (1, 'Chong Yue')
# (2, 'Ling')
# (3, 'Shu')
# (4, 'Nian')
# (5, 'Dusk')

# %%
for index, name in enumerate(siblings):
    op_bday=birthdays[index]
    print(f"{name}\'s birthday is {op_bday}!")
# Out:
# Chong Yue's birthday is 1/1!
# Ling's birthday is 3/3!
# Shu's birthday is 6/6!
# Nian's birthday is 9/9!
# Dusk's birthday is 11/11!

# %%
type(index)
# Out:
# int

# %% [markdown]
# `enumerate()` is a function that can be used in a loop
# `enumerate(argument, x)` assigns a number to each element in a list/array `argument` starting from `x` (0 by default)
# that number is assigned the variable `y` in `for y in enumerate(argument,x)`
# `print(y)` only produces the last count assigned via `enumerate()`
# `for y in enumerate(argument,x)` gives the count number and corresponding list/array element
#
# in the line `op_bday=birthdays[index]`,
# - the variable `op_bday` is assigned the value from `birthdays` list corresponding to the int in `index`
# - the ints in `index` are obtained from the enumeration of `siblings` (this is why it does not work when setting `x` to 1, as Python is zero-indexed)
# - it then prints out the corresponding `name` that assigned the `index` int value in line 1, and loops for each subsequent enumerated value

# %% [markdown]
# `enumerate()` is an **iterator**. it works similarly to
# ```
# count=0
# for x in list:
#     print(x)
#     count+=1
# ```
# since it expands the list to have an additional integer as a dimension for each element, 2 variables have to be defined in the `for` loop
# the enumerate counter can be used as an index for another list in order to correspond its entries to a certain list

# %% [markdown]
# ## 1.3 for with range

# %%
for i in range(4,1,-1):
    print(i)
# Out:
# 4
# 3
# 2

# %%
for i in range(len(siblings)):
    name=siblings[i]
    bday=birthdays[i]
    print(f"{name}\'s birthday is {bday}!")
# Out:
# Chong Yue's birthday is 1/1!
# Ling's birthday is 3/3!
# Shu's birthday is 6/6!
# Nian's birthday is 9/9!
# Dusk's birthday is 11/11!

# %%
len(siblings)
# Out:
# 5

# %% [markdown]
# `range(x,y,z)` is another function that is used in a loop to run it a certain number of times
# - `x`: starting value (0 by default)
# - `y`: ending value (used if only 1 value is input to determine how many times the loop is run)
# - `z`: step size (1 by default)
# - assuming an increasing integer structure from `x` to `y`, `range()` will run from `x` at intervals of `z` up to $(y-1)$
# - if $x\gt y$ and `z` is negative, the loop can run in reverse from `x` to $(y+1)$ at intervals of `z`
#
# line 1: uses `len(siblings)` to determine how many loops to be run, and assigns the loop count to `i`
# line 2: assigns variable `name` to index `i` in list `siblings`
# line 3: assigns variable `bday` to index `i` in list `birthdays`
# line 4: prints the corresponding `name` and `bday`
# _note: `len(siblings)` returning 5 means the loop will run 5 times for `i` values of 0,1,2,3,4 , which are indexed to the lists `siblings` and `birthdays`_

# %% [markdown]
# # 2 while

# %%
counter = 0
while counter < 5: # while counter < counter+1
    print(counter)
    counter+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# `while condition` loops check if the condition is True, and executes the code block if the condition is true
# it loops until the condition is false

# %%
time=0
distance=1

while distance >0:
    distance/=2
    time+=1
    print(f"after {time}, the remaining distance is {distance}")
# Out:
# after 1, the remaining distance is 0.5
# after 2, the remaining distance is 0.25
# after 3, the remaining distance is 0.125
# after 4, the remaining distance is 0.0625
# after 5, the remaining distance is 0.03125
# after 6, the remaining distance is 0.015625
# after 7, the remaining distance is 0.0078125
# after 8, the remaining distance is 0.00390625
# after 9, the remaining distance is 0.001953125
# after 10, the remaining distance is 0.0009765625
# after 11, the remaining distance is 0.00048828125
# after 12, the remaining distance is 0.000244140625
# after 13, the remaining distance is 0.0001220703125
# after 14, the remaining distance is 6.103515625e-05
# after 15, the remaining distance is 3.0517578125e-05
# after 16, the remaining distance is 1.52587890625e-05
# after 17, the remaining distance is 7.62939453125e-06
# after 18, the remaining distance is 3.814697265625e-06
# after 19, the remaining distance is 1.9073486328125e-06
# after 20, the remaining distance is 9.5367431640625e-07
# after 21, the remaining distance is 4.76837158203125e-07
# after 22, the remaining distance is 2.384185791015625e-07
# after 23, the remaining distance is 1.1920928955078125e-07
# after 24, the remaining distance is 5.960464477539063e-08
# after 25, the remaining distance is 2.9802322387695312e-08
# after 26, the remaining distance is 1.4901161193847656e-08
# after 27, the remaining distance is 7.450580596923828e-09
# after 28, the remaining distance is 3.725290298461914e-09
# after 29, the remaining distance is 1.862645149230957e-09
# after 30, the remaining distance is 9.313225746154785e-10
# after 31, the remaining distance is 4.656612873077393e-10
# after 32, the remaining distance is 2.3283064365386963e-10
# after 33, the remaining distance is 1.1641532182693481e-10
# after 34, the remaining distance is 5.820766091346741e-11
# after 35, the remaining distance is 2.9103830456733704e-11
# after 36, the remaining distance is 1.4551915228366852e-11
# after 37, the remaining distance is 7.275957614183426e-12
# after 38, the remaining distance is 3.637978807091713e-12
# after 39, the remaining distance is 1.8189894035458565e-12
# after 40, the remaining distance is 9.094947017729282e-13
# after 41, the remaining distance is 4.547473508864641e-13
# after 42, the remaining distance is 2.2737367544323206e-13
# after 43, the remaining distance is 1.1368683772161603e-13
# after 44, the remaining distance is 5.684341886080802e-14
# after 45, the remaining distance is 2.842170943040401e-14
# after 46, the remaining distance is 1.4210854715202004e-14
# after 47, the remaining distance is 7.105427357601002e-15
# after 48, the remaining distance is 3.552713678800501e-15
# after 49, the remaining distance is 1.7763568394002505e-15
# after 50, the remaining distance is 8.881784197001252e-16
# after 51, the remaining distance is 4.440892098500626e-16
# after 52, the remaining distance is 2.220446049250313e-16
# after 53, the remaining distance is 1.1102230246251565e-16
# after 54, the remaining distance is 5.551115123125783e-17
# after 55, the remaining distance is 2.7755575615628914e-17
# after 56, the remaining distance is 1.3877787807814457e-17
# after 57, the remaining distance is 6.938893903907228e-18
# after 58, the remaining distance is 3.469446951953614e-18
# after 59, the remaining distance is 1.734723475976807e-18
# after 60, the remaining distance is 8.673617379884035e-19
# after 61, the remaining distance is 4.336808689942018e-19
# after 62, the remaining distance is 2.168404344971009e-19
# after 63, the remaining distance is 1.0842021724855044e-19
# after 64, the remaining distance is 5.421010862427522e-20
# after 65, the remaining distance is 2.710505431213761e-20
# after 66, the remaining distance is 1.3552527156068805e-20
# after 67, the remaining distance is 6.776263578034403e-21
# after 68, the remaining distance is 3.3881317890172014e-21
# after 69, the remaining distance is 1.6940658945086007e-21
# after 70, the remaining distance is 8.470329472543003e-22
# after 71, the remaining distance is 4.235164736271502e-22
# after 72, the remaining distance is 2.117582368135751e-22
# after 73, the remaining distance is 1.0587911840678754e-22
# after 74, the remaining distance is 5.293955920339377e-23
# after 75, the remaining distance is 2.6469779601696886e-23
# after 76, the remaining distance is 1.3234889800848443e-23
# after 77, the remaining distance is 6.617444900424222e-24
# after 78, the remaining distance is 3.308722450212111e-24
# after 79, the remaining distance is 1.6543612251060553e-24
# after 80, the remaining distance is 8.271806125530277e-25
# after 81, the remaining distance is 4.1359030627651384e-25
# after 82, the remaining distance is 2.0679515313825692e-25
# after 83, the remaining distance is 1.0339757656912846e-25
# after 84, the remaining distance is 5.169878828456423e-26
# after 85, the remaining distance is 2.5849394142282115e-26
# after 86, the remaining distance is 1.2924697071141057e-26
# after 87, the remaining distance is 6.462348535570529e-27
# after 88, the remaining distance is 3.2311742677852644e-27
# after 89, the remaining distance is 1.6155871338926322e-27
# after 90, the remaining distance is 8.077935669463161e-28
# after 91, the remaining distance is 4.0389678347315804e-28
# after 92, the remaining distance is 2.0194839173657902e-28
# after 93, the remaining distance is 1.0097419586828951e-28
# after 94, the remaining distance is 5.048709793414476e-29
# after 95, the remaining distance is 2.524354896707238e-29
# after 96, the remaining distance is 1.262177448353619e-29
# after 97, the remaining distance is 6.310887241768095e-30
# after 98, the remaining distance is 3.1554436208840472e-30
# after 99, the remaining distance is 1.5777218104420236e-30
# after 100, the remaining distance is 7.888609052210118e-31
# after 101, the remaining distance is 3.944304526105059e-31
# after 102, the remaining distance is 1.9721522630525295e-31
# after 103, the remaining distance is 9.860761315262648e-32
# after 104, the remaining distance is 4.930380657631324e-32
# after 105, the remaining distance is 2.465190328815662e-32
# after 106, the remaining distance is 1.232595164407831e-32
# after 107, the remaining distance is 6.162975822039155e-33
# after 108, the remaining distance is 3.0814879110195774e-33
# after 109, the remaining distance is 1.5407439555097887e-33
# after 110, the remaining distance is 7.703719777548943e-34
# after 111, the remaining distance is 3.851859888774472e-34
# after 112, the remaining distance is 1.925929944387236e-34
# after 113, the remaining distance is 9.62964972193618e-35
# after 114, the remaining distance is 4.81482486096809e-35
# after 115, the remaining distance is 2.407412430484045e-35
# after 116, the remaining distance is 1.2037062152420224e-35
# after 117, the remaining distance is 6.018531076210112e-36
# after 118, the remaining distance is 3.009265538105056e-36
# after 119, the remaining distance is 1.504632769052528e-36
# after 120, the remaining distance is 7.52316384526264e-37
# after 121, the remaining distance is 3.76158192263132e-37
# after 122, the remaining distance is 1.88079096131566e-37
# after 123, the remaining distance is 9.4039548065783e-38
# after 124, the remaining distance is 4.70197740328915e-38
# after 125, the remaining distance is 2.350988701644575e-38
# after 126, the remaining distance is 1.1754943508222875e-38
# after 127, the remaining distance is 5.877471754111438e-39
# after 128, the remaining distance is 2.938735877055719e-39
# after 129, the remaining distance is 1.4693679385278594e-39
# after 130, the remaining distance is 7.346839692639297e-40
# after 131, the remaining distance is 3.6734198463196485e-40
# after 132, the remaining distance is 1.8367099231598242e-40
# after 133, the remaining distance is 9.183549615799121e-41
# after 134, the remaining distance is 4.591774807899561e-41
# after 135, the remaining distance is 2.2958874039497803e-41
# after 136, the remaining distance is 1.1479437019748901e-41
# after 137, the remaining distance is 5.739718509874451e-42
# after 138, the remaining distance is 2.8698592549372254e-42
# after 139, the remaining distance is 1.4349296274686127e-42
# after 140, the remaining distance is 7.174648137343064e-43
# after 141, the remaining distance is 3.587324068671532e-43
# after 142, the remaining distance is 1.793662034335766e-43
# after 143, the remaining distance is 8.96831017167883e-44
# after 144, the remaining distance is 4.484155085839415e-44
# after 145, the remaining distance is 2.2420775429197073e-44
# after 146, the remaining distance is 1.1210387714598537e-44
# after 147, the remaining distance is 5.605193857299268e-45
# after 148, the remaining distance is 2.802596928649634e-45
# after 149, the remaining distance is 1.401298464324817e-45
# after 150, the remaining distance is 7.006492321624085e-46
# after 151, the remaining distance is 3.503246160812043e-46
# after 152, the remaining distance is 1.7516230804060213e-46
# after 153, the remaining distance is 8.758115402030107e-47
# after 154, the remaining distance is 4.3790577010150533e-47
# after 155, the remaining distance is 2.1895288505075267e-47
# after 156, the remaining distance is 1.0947644252537633e-47
# after 157, the remaining distance is 5.473822126268817e-48
# after 158, the remaining distance is 2.7369110631344083e-48
# after 159, the remaining distance is 1.3684555315672042e-48
# after 160, the remaining distance is 6.842277657836021e-49
# after 161, the remaining distance is 3.4211388289180104e-49
# after 162, the remaining distance is 1.7105694144590052e-49
# after 163, the remaining distance is 8.552847072295026e-50
# after 164, the remaining distance is 4.276423536147513e-50
# after 165, the remaining distance is 2.1382117680737565e-50
# after 166, the remaining distance is 1.0691058840368783e-50
# after 167, the remaining distance is 5.345529420184391e-51
# after 168, the remaining distance is 2.6727647100921956e-51
# after 169, the remaining distance is 1.3363823550460978e-51
# after 170, the remaining distance is 6.681911775230489e-52
# after 171, the remaining distance is 3.3409558876152446e-52
# after 172, the remaining distance is 1.6704779438076223e-52
# after 173, the remaining distance is 8.352389719038111e-53
# after 174, the remaining distance is 4.176194859519056e-53
# after 175, the remaining distance is 2.088097429759528e-53
# after 176, the remaining distance is 1.044048714879764e-53
# after 177, the remaining distance is 5.22024357439882e-54
# after 178, the remaining distance is 2.61012178719941e-54
# after 179, the remaining distance is 1.305060893599705e-54
# after 180, the remaining distance is 6.525304467998525e-55
# after 181, the remaining distance is 3.2626522339992623e-55
# after 182, the remaining distance is 1.6313261169996311e-55
# after 183, the remaining distance is 8.156630584998156e-56
# after 184, the remaining distance is 4.078315292499078e-56
# after 185, the remaining distance is 2.039157646249539e-56
# after 186, the remaining distance is 1.0195788231247695e-56
# after 187, the remaining distance is 5.0978941156238473e-57
# after 188, the remaining distance is 2.5489470578119236e-57
# after 189, the remaining distance is 1.2744735289059618e-57
# after 190, the remaining distance is 6.372367644529809e-58
# after 191, the remaining distance is 3.1861838222649046e-58
# after 192, the remaining distance is 1.5930919111324523e-58
# after 193, the remaining distance is 7.965459555662261e-59
# after 194, the remaining distance is 3.982729777831131e-59
# after 195, the remaining distance is 1.9913648889155653e-59
# after 196, the remaining distance is 9.956824444577827e-60
# after 197, the remaining distance is 4.9784122222889134e-60
# after 198, the remaining distance is 2.4892061111444567e-60
# after 199, the remaining distance is 1.2446030555722283e-60
# after 200, the remaining distance is 6.223015277861142e-61
# after 201, the remaining distance is 3.111507638930571e-61
# after 202, the remaining distance is 1.5557538194652854e-61
# after 203, the remaining distance is 7.778769097326427e-62
# after 204, the remaining distance is 3.8893845486632136e-62
# after 205, the remaining distance is 1.9446922743316068e-62
# after 206, the remaining distance is 9.723461371658034e-63
# after 207, the remaining distance is 4.861730685829017e-63
# after 208, the remaining distance is 2.4308653429145085e-63
# after 209, the remaining distance is 1.2154326714572542e-63
# after 210, the remaining distance is 6.077163357286271e-64
# after 211, the remaining distance is 3.0385816786431356e-64
# after 212, the remaining distance is 1.5192908393215678e-64
# after 213, the remaining distance is 7.596454196607839e-65
# after 214, the remaining distance is 3.7982270983039195e-65
# after 215, the remaining distance is 1.8991135491519597e-65
# after 216, the remaining distance is 9.495567745759799e-66
# after 217, the remaining distance is 4.7477838728798994e-66
# after 218, the remaining distance is 2.3738919364399497e-66
# after 219, the remaining distance is 1.1869459682199748e-66
# after 220, the remaining distance is 5.934729841099874e-67
# after 221, the remaining distance is 2.967364920549937e-67
# after 222, the remaining distance is 1.4836824602749686e-67
# after 223, the remaining distance is 7.418412301374843e-68
# after 224, the remaining distance is 3.7092061506874214e-68
# after 225, the remaining distance is 1.8546030753437107e-68
# after 226, the remaining distance is 9.273015376718553e-69
# after 227, the remaining distance is 4.636507688359277e-69
# after 228, the remaining distance is 2.3182538441796384e-69
# after 229, the remaining distance is 1.1591269220898192e-69
# after 230, the remaining distance is 5.795634610449096e-70
# after 231, the remaining distance is 2.897817305224548e-70
# after 232, the remaining distance is 1.448908652612274e-70
# after 233, the remaining distance is 7.24454326306137e-71
# after 234, the remaining distance is 3.622271631530685e-71
# after 235, the remaining distance is 1.8111358157653425e-71
# after 236, the remaining distance is 9.055679078826712e-72
# after 237, the remaining distance is 4.527839539413356e-72
# after 238, the remaining distance is 2.263919769706678e-72
# after 239, the remaining distance is 1.131959884853339e-72
# after 240, the remaining distance is 5.659799424266695e-73
# after 241, the remaining distance is 2.8298997121333476e-73
# after 242, the remaining distance is 1.4149498560666738e-73
# after 243, the remaining distance is 7.074749280333369e-74
# after 244, the remaining distance is 3.5373746401666845e-74
# after 245, the remaining distance is 1.7686873200833423e-74
# after 246, the remaining distance is 8.843436600416711e-75
# after 247, the remaining distance is 4.421718300208356e-75
# after 248, the remaining distance is 2.210859150104178e-75
# after 249, the remaining distance is 1.105429575052089e-75
# after 250, the remaining distance is 5.527147875260445e-76
# after 251, the remaining distance is 2.7635739376302223e-76
# after 252, the remaining distance is 1.3817869688151111e-76
# after 253, the remaining distance is 6.908934844075556e-77
# after 254, the remaining distance is 3.454467422037778e-77
# after 255, the remaining distance is 1.727233711018889e-77
# after 256, the remaining distance is 8.636168555094445e-78
# after 257, the remaining distance is 4.3180842775472223e-78
# after 258, the remaining distance is 2.1590421387736112e-78
# after 259, the remaining distance is 1.0795210693868056e-78
# after 260, the remaining distance is 5.397605346934028e-79
# after 261, the remaining distance is 2.698802673467014e-79
# after 262, the remaining distance is 1.349401336733507e-79
# after 263, the remaining distance is 6.747006683667535e-80
# after 264, the remaining distance is 3.3735033418337674e-80
# after 265, the remaining distance is 1.6867516709168837e-80
# after 266, the remaining distance is 8.433758354584419e-81
# after 267, the remaining distance is 4.2168791772922093e-81
# after 268, the remaining distance is 2.1084395886461046e-81
# after 269, the remaining distance is 1.0542197943230523e-81
# after 270, the remaining distance is 5.271098971615262e-82
# after 271, the remaining distance is 2.635549485807631e-82
# after 272, the remaining distance is 1.3177747429038154e-82
# after 273, the remaining distance is 6.588873714519077e-83
# after 274, the remaining distance is 3.2944368572595385e-83
# after 275, the remaining distance is 1.6472184286297693e-83
# after 276, the remaining distance is 8.236092143148846e-84
# after 277, the remaining distance is 4.118046071574423e-84
# after 278, the remaining distance is 2.0590230357872116e-84
# after 279, the remaining distance is 1.0295115178936058e-84
# after 280, the remaining distance is 5.147557589468029e-85
# after 281, the remaining distance is 2.5737787947340145e-85
# after 282, the remaining distance is 1.2868893973670072e-85
# after 283, the remaining distance is 6.434446986835036e-86
# after 284, the remaining distance is 3.217223493417518e-86
# after 285, the remaining distance is 1.608611746708759e-86
# after 286, the remaining distance is 8.043058733543795e-87
# after 287, the remaining distance is 4.021529366771898e-87
# after 288, the remaining distance is 2.010764683385949e-87
# after 289, the remaining distance is 1.0053823416929744e-87
# after 290, the remaining distance is 5.026911708464872e-88
# after 291, the remaining distance is 2.513455854232436e-88
# after 292, the remaining distance is 1.256727927116218e-88
# after 293, the remaining distance is 6.28363963558109e-89
# after 294, the remaining distance is 3.141819817790545e-89
# after 295, the remaining distance is 1.5709099088952725e-89
# after 296, the remaining distance is 7.854549544476363e-90
# after 297, the remaining distance is 3.9272747722381812e-90
# after 298, the remaining distance is 1.9636373861190906e-90
# after 299, the remaining distance is 9.818186930595453e-91
# after 300, the remaining distance is 4.909093465297727e-91
# after 301, the remaining distance is 2.4545467326488633e-91
# after 302, the remaining distance is 1.2272733663244316e-91
# after 303, the remaining distance is 6.136366831622158e-92
# after 304, the remaining distance is 3.068183415811079e-92
# after 305, the remaining distance is 1.5340917079055395e-92
# after 306, the remaining distance is 7.670458539527698e-93
# after 307, the remaining distance is 3.835229269763849e-93
# after 308, the remaining distance is 1.9176146348819244e-93
# after 309, the remaining distance is 9.588073174409622e-94
# after 310, the remaining distance is 4.794036587204811e-94
# after 311, the remaining distance is 2.3970182936024055e-94
# after 312, the remaining distance is 1.1985091468012028e-94
# after 313, the remaining distance is 5.992545734006014e-95
# after 314, the remaining distance is 2.996272867003007e-95
# after 315, the remaining distance is 1.4981364335015035e-95
# after 316, the remaining distance is 7.490682167507517e-96
# after 317, the remaining distance is 3.745341083753759e-96
# after 318, the remaining distance is 1.8726705418768793e-96
# after 319, the remaining distance is 9.363352709384397e-97
# after 320, the remaining distance is 4.6816763546921983e-97
# after 321, the remaining distance is 2.3408381773460992e-97
# after 322, the remaining distance is 1.1704190886730496e-97
# after 323, the remaining distance is 5.852095443365248e-98
# after 324, the remaining distance is 2.926047721682624e-98
# after 325, the remaining distance is 1.463023860841312e-98
# after 326, the remaining distance is 7.31511930420656e-99
# after 327, the remaining distance is 3.65755965210328e-99
# after 328, the remaining distance is 1.82877982605164e-99
# after 329, the remaining distance is 9.1438991302582e-100
# after 330, the remaining distance is 4.5719495651291e-100
# after 331, the remaining distance is 2.28597478256455e-100
# after 332, the remaining distance is 1.142987391282275e-100
# after 333, the remaining distance is 5.714936956411375e-101
# after 334, the remaining distance is 2.8574684782056875e-101
# after 335, the remaining distance is 1.4287342391028437e-101
# after 336, the remaining distance is 7.143671195514219e-102
# after 337, the remaining distance is 3.5718355977571093e-102
# after 338, the remaining distance is 1.7859177988785547e-102
# after 339, the remaining distance is 8.929588994392773e-103
# after 340, the remaining distance is 4.464794497196387e-103
# after 341, the remaining distance is 2.2323972485981933e-103
# after 342, the remaining distance is 1.1161986242990967e-103
# after 343, the remaining distance is 5.5809931214954833e-104
# after 344, the remaining distance is 2.7904965607477417e-104
# after 345, the remaining distance is 1.3952482803738708e-104
# after 346, the remaining distance is 6.976241401869354e-105
# after 347, the remaining distance is 3.488120700934677e-105
# after 348, the remaining distance is 1.7440603504673385e-105
# after 349, the remaining distance is 8.720301752336693e-106
# after 350, the remaining distance is 4.3601508761683463e-106
# after 351, the remaining distance is 2.1800754380841732e-106
# after 352, the remaining distance is 1.0900377190420866e-106
# after 353, the remaining distance is 5.450188595210433e-107
# after 354, the remaining distance is 2.7250942976052165e-107
# after 355, the remaining distance is 1.3625471488026082e-107
# after 356, the remaining distance is 6.812735744013041e-108
# after 357, the remaining distance is 3.4063678720065206e-108
# after 358, the remaining distance is 1.7031839360032603e-108
# after 359, the remaining distance is 8.515919680016301e-109
# after 360, the remaining distance is 4.257959840008151e-109
# after 361, the remaining distance is 2.1289799200040754e-109
# after 362, the remaining distance is 1.0644899600020377e-109
# after 363, the remaining distance is 5.3224498000101884e-110
# after 364, the remaining distance is 2.6612249000050942e-110
# after 365, the remaining distance is 1.3306124500025471e-110
# after 366, the remaining distance is 6.653062250012736e-111
# after 367, the remaining distance is 3.326531125006368e-111
# after 368, the remaining distance is 1.663265562503184e-111
# after 369, the remaining distance is 8.31632781251592e-112
# after 370, the remaining distance is 4.15816390625796e-112
# after 371, the remaining distance is 2.07908195312898e-112
# after 372, the remaining distance is 1.03954097656449e-112
# after 373, the remaining distance is 5.19770488282245e-113
# after 374, the remaining distance is 2.598852441411225e-113
# after 375, the remaining distance is 1.2994262207056124e-113
# after 376, the remaining distance is 6.497131103528062e-114
# after 377, the remaining distance is 3.248565551764031e-114
# after 378, the remaining distance is 1.6242827758820155e-114
# after 379, the remaining distance is 8.121413879410078e-115
# after 380, the remaining distance is 4.060706939705039e-115
# after 381, the remaining distance is 2.0303534698525194e-115
# after 382, the remaining distance is 1.0151767349262597e-115
# after 383, the remaining distance is 5.075883674631299e-116
# after 384, the remaining distance is 2.5379418373156492e-116
# after 385, the remaining distance is 1.2689709186578246e-116
# after 386, the remaining distance is 6.344854593289123e-117
# after 387, the remaining distance is 3.1724272966445615e-117
# after 388, the remaining distance is 1.5862136483222808e-117
# after 389, the remaining distance is 7.931068241611404e-118
# after 390, the remaining distance is 3.965534120805702e-118
# after 391, the remaining distance is 1.982767060402851e-118
# after 392, the remaining distance is 9.913835302014255e-119
# after 393, the remaining distance is 4.9569176510071274e-119
# after 394, the remaining distance is 2.4784588255035637e-119
# after 395, the remaining distance is 1.2392294127517818e-119
# after 396, the remaining distance is 6.196147063758909e-120
# after 397, the remaining distance is 3.0980735318794546e-120
# after 398, the remaining distance is 1.5490367659397273e-120
# after 399, the remaining distance is 7.745183829698637e-121
# after 400, the remaining distance is 3.8725919148493183e-121
# after 401, the remaining distance is 1.9362959574246591e-121
# after 402, the remaining distance is 9.681479787123296e-122
# after 403, the remaining distance is 4.840739893561648e-122
# after 404, the remaining distance is 2.420369946780824e-122
# after 405, the remaining distance is 1.210184973390412e-122
# after 406, the remaining distance is 6.05092486695206e-123
# after 407, the remaining distance is 3.02546243347603e-123
# after 408, the remaining distance is 1.512731216738015e-123
# after 409, the remaining distance is 7.563656083690075e-124
# after 410, the remaining distance is 3.7818280418450374e-124
# after 411, the remaining distance is 1.8909140209225187e-124
# after 412, the remaining distance is 9.454570104612593e-125
# after 413, the remaining distance is 4.727285052306297e-125
# after 414, the remaining distance is 2.3636425261531484e-125
# after 415, the remaining distance is 1.1818212630765742e-125
# after 416, the remaining distance is 5.909106315382871e-126
# after 417, the remaining distance is 2.9545531576914354e-126
# after 418, the remaining distance is 1.4772765788457177e-126
# after 419, the remaining distance is 7.386382894228589e-127
# after 420, the remaining distance is 3.6931914471142943e-127
# after 421, the remaining distance is 1.8465957235571472e-127
# after 422, the remaining distance is 9.232978617785736e-128
# after 423, the remaining distance is 4.616489308892868e-128
# after 424, the remaining distance is 2.308244654446434e-128
# after 425, the remaining distance is 1.154122327223217e-128
# after 426, the remaining distance is 5.770611636116085e-129
# after 427, the remaining distance is 2.8853058180580424e-129
# after 428, the remaining distance is 1.4426529090290212e-129
# after 429, the remaining distance is 7.213264545145106e-130
# after 430, the remaining distance is 3.606632272572553e-130
# after 431, the remaining distance is 1.8033161362862765e-130
# after 432, the remaining distance is 9.016580681431383e-131
# after 433, the remaining distance is 4.5082903407156913e-131
# after 434, the remaining distance is 2.2541451703578456e-131
# after 435, the remaining distance is 1.1270725851789228e-131
# after 436, the remaining distance is 5.635362925894614e-132
# after 437, the remaining distance is 2.817681462947307e-132
# after 438, the remaining distance is 1.4088407314736535e-132
# after 439, the remaining distance is 7.044203657368268e-133
# after 440, the remaining distance is 3.522101828684134e-133
# after 441, the remaining distance is 1.761050914342067e-133
# after 442, the remaining distance is 8.805254571710335e-134
# after 443, the remaining distance is 4.4026272858551673e-134
# after 444, the remaining distance is 2.2013136429275836e-134
# after 445, the remaining distance is 1.1006568214637918e-134
# after 446, the remaining distance is 5.503284107318959e-135
# after 447, the remaining distance is 2.7516420536594796e-135
# after 448, the remaining distance is 1.3758210268297398e-135
# after 449, the remaining distance is 6.879105134148699e-136
# after 450, the remaining distance is 3.4395525670743494e-136
# after 451, the remaining distance is 1.7197762835371747e-136
# after 452, the remaining distance is 8.598881417685874e-137
# after 453, the remaining distance is 4.299440708842937e-137
# after 454, the remaining distance is 2.1497203544214684e-137
# after 455, the remaining distance is 1.0748601772107342e-137
# after 456, the remaining distance is 5.374300886053671e-138
# after 457, the remaining distance is 2.6871504430268355e-138
# after 458, the remaining distance is 1.3435752215134178e-138
# after 459, the remaining distance is 6.717876107567089e-139
# after 460, the remaining distance is 3.3589380537835444e-139
# after 461, the remaining distance is 1.6794690268917722e-139
# after 462, the remaining distance is 8.397345134458861e-140
# after 463, the remaining distance is 4.1986725672294305e-140
# after 464, the remaining distance is 2.0993362836147152e-140
# after 465, the remaining distance is 1.0496681418073576e-140
# after 466, the remaining distance is 5.248340709036788e-141
# after 467, the remaining distance is 2.624170354518394e-141
# after 468, the remaining distance is 1.312085177259197e-141
# after 469, the remaining distance is 6.560425886295985e-142
# after 470, the remaining distance is 3.2802129431479926e-142
# after 471, the remaining distance is 1.6401064715739963e-142
# after 472, the remaining distance is 8.200532357869981e-143
# after 473, the remaining distance is 4.100266178934991e-143
# after 474, the remaining distance is 2.0501330894674953e-143
# after 475, the remaining distance is 1.0250665447337477e-143
# after 476, the remaining distance is 5.1253327236687384e-144
# after 477, the remaining distance is 2.5626663618343692e-144
# after 478, the remaining distance is 1.2813331809171846e-144
# after 479, the remaining distance is 6.406665904585923e-145
# after 480, the remaining distance is 3.2033329522929615e-145
# after 481, the remaining distance is 1.6016664761464807e-145
# after 482, the remaining distance is 8.008332380732404e-146
# after 483, the remaining distance is 4.004166190366202e-146
# after 484, the remaining distance is 2.002083095183101e-146
# after 485, the remaining distance is 1.0010415475915505e-146
# after 486, the remaining distance is 5.0052077379577523e-147
# after 487, the remaining distance is 2.5026038689788762e-147
# after 488, the remaining distance is 1.2513019344894381e-147
# after 489, the remaining distance is 6.256509672447191e-148
# after 490, the remaining distance is 3.1282548362235952e-148
# after 491, the remaining distance is 1.5641274181117976e-148
# after 492, the remaining distance is 7.820637090558988e-149
# after 493, the remaining distance is 3.910318545279494e-149
# after 494, the remaining distance is 1.955159272639747e-149
# after 495, the remaining distance is 9.775796363198735e-150
# after 496, the remaining distance is 4.887898181599368e-150
# after 497, the remaining distance is 2.443949090799684e-150
# after 498, the remaining distance is 1.221974545399842e-150
# after 499, the remaining distance is 6.10987272699921e-151
# after 500, the remaining distance is 3.054936363499605e-151
# after 501, the remaining distance is 1.5274681817498023e-151
# after 502, the remaining distance is 7.637340908749012e-152
# after 503, the remaining distance is 3.818670454374506e-152
# after 504, the remaining distance is 1.909335227187253e-152
# after 505, the remaining distance is 9.546676135936265e-153
# after 506, the remaining distance is 4.7733380679681323e-153
# after 507, the remaining distance is 2.3866690339840662e-153
# after 508, the remaining distance is 1.1933345169920331e-153
# after 509, the remaining distance is 5.966672584960166e-154
# after 510, the remaining distance is 2.983336292480083e-154
# after 511, the remaining distance is 1.4916681462400413e-154
# after 512, the remaining distance is 7.458340731200207e-155
# after 513, the remaining distance is 3.7291703656001034e-155
# after 514, the remaining distance is 1.8645851828000517e-155
# after 515, the remaining distance is 9.322925914000258e-156
# after 516, the remaining distance is 4.661462957000129e-156
# after 517, the remaining distance is 2.3307314785000646e-156
# after 518, the remaining distance is 1.1653657392500323e-156
# after 519, the remaining distance is 5.826828696250162e-157
# after 520, the remaining distance is 2.913414348125081e-157
# after 521, the remaining distance is 1.4567071740625404e-157
# after 522, the remaining distance is 7.283535870312702e-158
# after 523, the remaining distance is 3.641767935156351e-158
# after 524, the remaining distance is 1.8208839675781755e-158
# after 525, the remaining distance is 9.104419837890877e-159
# after 526, the remaining distance is 4.552209918945439e-159
# after 527, the remaining distance is 2.2761049594727193e-159
# after 528, the remaining distance is 1.1380524797363597e-159
# after 529, the remaining distance is 5.6902623986817984e-160
# after 530, the remaining distance is 2.8451311993408992e-160
# after 531, the remaining distance is 1.4225655996704496e-160
# after 532, the remaining distance is 7.112827998352248e-161
# after 533, the remaining distance is 3.556413999176124e-161
# after 534, the remaining distance is 1.778206999588062e-161
# after 535, the remaining distance is 8.89103499794031e-162
# after 536, the remaining distance is 4.445517498970155e-162
# after 537, the remaining distance is 2.2227587494850775e-162
# after 538, the remaining distance is 1.1113793747425387e-162
# after 539, the remaining distance is 5.556896873712694e-163
# after 540, the remaining distance is 2.778448436856347e-163
# after 541, the remaining distance is 1.3892242184281734e-163
# after 542, the remaining distance is 6.946121092140867e-164
# after 543, the remaining distance is 3.4730605460704336e-164
# after 544, the remaining distance is 1.7365302730352168e-164
# after 545, the remaining distance is 8.682651365176084e-165
# after 546, the remaining distance is 4.341325682588042e-165
# after 547, the remaining distance is 2.170662841294021e-165
# after 548, the remaining distance is 1.0853314206470105e-165
# after 549, the remaining distance is 5.426657103235053e-166
# after 550, the remaining distance is 2.7133285516175262e-166
# after 551, the remaining distance is 1.3566642758087631e-166
# after 552, the remaining distance is 6.783321379043816e-167
# after 553, the remaining distance is 3.391660689521908e-167
# after 554, the remaining distance is 1.695830344760954e-167
# after 555, the remaining distance is 8.47915172380477e-168
# after 556, the remaining distance is 4.239575861902385e-168
# after 557, the remaining distance is 2.1197879309511924e-168
# after 558, the remaining distance is 1.0598939654755962e-168
# after 559, the remaining distance is 5.299469827377981e-169
# after 560, the remaining distance is 2.6497349136889905e-169
# after 561, the remaining distance is 1.3248674568444952e-169
# after 562, the remaining distance is 6.624337284222476e-170
# after 563, the remaining distance is 3.312168642111238e-170
# after 564, the remaining distance is 1.656084321055619e-170
# after 565, the remaining distance is 8.280421605278095e-171
# after 566, the remaining distance is 4.140210802639048e-171
# after 567, the remaining distance is 2.070105401319524e-171
# after 568, the remaining distance is 1.035052700659762e-171
# after 569, the remaining distance is 5.17526350329881e-172
# after 570, the remaining distance is 2.587631751649405e-172
# after 571, the remaining distance is 1.2938158758247024e-172
# after 572, the remaining distance is 6.469079379123512e-173
# after 573, the remaining distance is 3.234539689561756e-173
# after 574, the remaining distance is 1.617269844780878e-173
# after 575, the remaining distance is 8.08634922390439e-174
# after 576, the remaining distance is 4.043174611952195e-174
# after 577, the remaining distance is 2.0215873059760975e-174
# after 578, the remaining distance is 1.0107936529880487e-174
# after 579, the remaining distance is 5.053968264940244e-175
# after 580, the remaining distance is 2.526984132470122e-175
# after 581, the remaining distance is 1.263492066235061e-175
# after 582, the remaining distance is 6.317460331175305e-176
# after 583, the remaining distance is 3.1587301655876523e-176
# after 584, the remaining distance is 1.5793650827938261e-176
# after 585, the remaining distance is 7.896825413969131e-177
# after 586, the remaining distance is 3.9484127069845653e-177
# after 587, the remaining distance is 1.9742063534922827e-177
# after 588, the remaining distance is 9.871031767461413e-178
# after 589, the remaining distance is 4.935515883730707e-178
# after 590, the remaining distance is 2.4677579418653533e-178
# after 591, the remaining distance is 1.2338789709326767e-178
# after 592, the remaining distance is 6.169394854663383e-179
# after 593, the remaining distance is 3.084697427331692e-179
# after 594, the remaining distance is 1.542348713665846e-179
# after 595, the remaining distance is 7.71174356832923e-180
# after 596, the remaining distance is 3.855871784164615e-180
# after 597, the remaining distance is 1.9279358920823073e-180
# after 598, the remaining distance is 9.639679460411536e-181
# after 599, the remaining distance is 4.819839730205768e-181
# after 600, the remaining distance is 2.409919865102884e-181
# after 601, the remaining distance is 1.204959932551442e-181
# after 602, the remaining distance is 6.02479966275721e-182
# after 603, the remaining distance is 3.012399831378605e-182
# after 604, the remaining distance is 1.5061999156893026e-182
# after 605, the remaining distance is 7.530999578446513e-183
# after 606, the remaining distance is 3.7654997892232564e-183
# after 607, the remaining distance is 1.8827498946116282e-183
# after 608, the remaining distance is 9.413749473058141e-184
# after 609, the remaining distance is 4.706874736529071e-184
# after 610, the remaining distance is 2.3534373682645353e-184
# after 611, the remaining distance is 1.1767186841322676e-184
# after 612, the remaining distance is 5.883593420661338e-185
# after 613, the remaining distance is 2.941796710330669e-185
# after 614, the remaining distance is 1.4708983551653345e-185
# after 615, the remaining distance is 7.354491775826673e-186
# after 616, the remaining distance is 3.6772458879133364e-186
# after 617, the remaining distance is 1.8386229439566682e-186
# after 618, the remaining distance is 9.193114719783341e-187
# after 619, the remaining distance is 4.5965573598916705e-187
# after 620, the remaining distance is 2.2982786799458352e-187
# after 621, the remaining distance is 1.1491393399729176e-187
# after 622, the remaining distance is 5.745696699864588e-188
# after 623, the remaining distance is 2.872848349932294e-188
# after 624, the remaining distance is 1.436424174966147e-188
# after 625, the remaining distance is 7.182120874830735e-189
# after 626, the remaining distance is 3.5910604374153675e-189
# after 627, the remaining distance is 1.7955302187076838e-189
# after 628, the remaining distance is 8.977651093538419e-190
# after 629, the remaining distance is 4.4888255467692094e-190
# after 630, the remaining distance is 2.2444127733846047e-190
# after 631, the remaining distance is 1.1222063866923024e-190
# after 632, the remaining distance is 5.611031933461512e-191
# after 633, the remaining distance is 2.805515966730756e-191
# after 634, the remaining distance is 1.402757983365378e-191
# after 635, the remaining distance is 7.01378991682689e-192
# after 636, the remaining distance is 3.506894958413445e-192
# after 637, the remaining distance is 1.7534474792067224e-192
# after 638, the remaining distance is 8.767237396033612e-193
# after 639, the remaining distance is 4.383618698016806e-193
# after 640, the remaining distance is 2.191809349008403e-193
# after 641, the remaining distance is 1.0959046745042015e-193
# after 642, the remaining distance is 5.479523372521008e-194
# after 643, the remaining distance is 2.739761686260504e-194
# after 644, the remaining distance is 1.369880843130252e-194
# after 645, the remaining distance is 6.84940421565126e-195
# after 646, the remaining distance is 3.42470210782563e-195
# after 647, the remaining distance is 1.712351053912815e-195
# after 648, the remaining distance is 8.561755269564074e-196
# after 649, the remaining distance is 4.280877634782037e-196
# after 650, the remaining distance is 2.1404388173910186e-196
# after 651, the remaining distance is 1.0702194086955093e-196
# after 652, the remaining distance is 5.351097043477547e-197
# after 653, the remaining distance is 2.6755485217387732e-197
# after 654, the remaining distance is 1.3377742608693866e-197
# after 655, the remaining distance is 6.688871304346933e-198
# after 656, the remaining distance is 3.3444356521734666e-198
# after 657, the remaining distance is 1.6722178260867333e-198
# after 658, the remaining distance is 8.361089130433666e-199
# after 659, the remaining distance is 4.180544565216833e-199
# after 660, the remaining distance is 2.0902722826084166e-199
# after 661, the remaining distance is 1.0451361413042083e-199
# after 662, the remaining distance is 5.225680706521042e-200
# after 663, the remaining distance is 2.612840353260521e-200
# after 664, the remaining distance is 1.3064201766302604e-200
# after 665, the remaining distance is 6.532100883151302e-201
# after 666, the remaining distance is 3.266050441575651e-201
# after 667, the remaining distance is 1.6330252207878255e-201
# after 668, the remaining distance is 8.165126103939127e-202
# after 669, the remaining distance is 4.082563051969564e-202
# after 670, the remaining distance is 2.041281525984782e-202
# after 671, the remaining distance is 1.020640762992391e-202
# after 672, the remaining distance is 5.103203814961955e-203
# after 673, the remaining distance is 2.5516019074809773e-203
# after 674, the remaining distance is 1.2758009537404886e-203
# after 675, the remaining distance is 6.379004768702443e-204
# after 676, the remaining distance is 3.1895023843512216e-204
# after 677, the remaining distance is 1.5947511921756108e-204
# after 678, the remaining distance is 7.973755960878054e-205
# after 679, the remaining distance is 3.986877980439027e-205
# after 680, the remaining distance is 1.9934389902195135e-205
# after 681, the remaining distance is 9.967194951097568e-206
# after 682, the remaining distance is 4.983597475548784e-206
# after 683, the remaining distance is 2.491798737774392e-206
# after 684, the remaining distance is 1.245899368887196e-206
# after 685, the remaining distance is 6.22949684443598e-207
# after 686, the remaining distance is 3.11474842221799e-207
# after 687, the remaining distance is 1.557374211108995e-207
# after 688, the remaining distance is 7.786871055544975e-208
# after 689, the remaining distance is 3.8934355277724873e-208
# after 690, the remaining distance is 1.9467177638862437e-208
# after 691, the remaining distance is 9.733588819431218e-209
# after 692, the remaining distance is 4.866794409715609e-209
# after 693, the remaining distance is 2.4333972048578046e-209
# after 694, the remaining distance is 1.2166986024289023e-209
# after 695, the remaining distance is 6.083493012144512e-210
# after 696, the remaining distance is 3.041746506072256e-210
# after 697, the remaining distance is 1.520873253036128e-210
# after 698, the remaining distance is 7.60436626518064e-211
# after 699, the remaining distance is 3.80218313259032e-211
# after 700, the remaining distance is 1.90109156629516e-211
# after 701, the remaining distance is 9.5054578314758e-212
# after 702, the remaining distance is 4.7527289157379e-212
# after 703, the remaining distance is 2.37636445786895e-212
# after 704, the remaining distance is 1.188182228934475e-212
# after 705, the remaining distance is 5.940911144672375e-213
# after 706, the remaining distance is 2.9704555723361872e-213
# after 707, the remaining distance is 1.4852277861680936e-213
# after 708, the remaining distance is 7.426138930840468e-214
# after 709, the remaining distance is 3.713069465420234e-214
# after 710, the remaining distance is 1.856534732710117e-214
# after 711, the remaining distance is 9.282673663550585e-215
# after 712, the remaining distance is 4.641336831775293e-215
# after 713, the remaining distance is 2.3206684158876463e-215
# after 714, the remaining distance is 1.1603342079438231e-215
# after 715, the remaining distance is 5.801671039719116e-216
# after 716, the remaining distance is 2.900835519859558e-216
# after 717, the remaining distance is 1.450417759929779e-216
# after 718, the remaining distance is 7.252088799648895e-217
# after 719, the remaining distance is 3.6260443998244473e-217
# after 720, the remaining distance is 1.8130221999122236e-217
# after 721, the remaining distance is 9.065110999561118e-218
# after 722, the remaining distance is 4.532555499780559e-218
# after 723, the remaining distance is 2.2662777498902796e-218
# after 724, the remaining distance is 1.1331388749451398e-218
# after 725, the remaining distance is 5.665694374725699e-219
# after 726, the remaining distance is 2.8328471873628494e-219
# after 727, the remaining distance is 1.4164235936814247e-219
# after 728, the remaining distance is 7.082117968407124e-220
# after 729, the remaining distance is 3.541058984203562e-220
# after 730, the remaining distance is 1.770529492101781e-220
# after 731, the remaining distance is 8.852647460508905e-221
# after 732, the remaining distance is 4.4263237302544523e-221
# after 733, the remaining distance is 2.2131618651272261e-221
# after 734, the remaining distance is 1.1065809325636131e-221
# after 735, the remaining distance is 5.5329046628180653e-222
# after 736, the remaining distance is 2.7664523314090327e-222
# after 737, the remaining distance is 1.3832261657045163e-222
# after 738, the remaining distance is 6.916130828522582e-223
# after 739, the remaining distance is 3.458065414261291e-223
# after 740, the remaining distance is 1.7290327071306454e-223
# after 741, the remaining distance is 8.645163535653227e-224
# after 742, the remaining distance is 4.322581767826614e-224
# after 743, the remaining distance is 2.161290883913307e-224
# after 744, the remaining distance is 1.0806454419566534e-224
# after 745, the remaining distance is 5.403227209783267e-225
# after 746, the remaining distance is 2.7016136048916335e-225
# after 747, the remaining distance is 1.3508068024458167e-225
# after 748, the remaining distance is 6.754034012229084e-226
# after 749, the remaining distance is 3.377017006114542e-226
# after 750, the remaining distance is 1.688508503057271e-226
# after 751, the remaining distance is 8.442542515286355e-227
# after 752, the remaining distance is 4.2212712576431773e-227
# after 753, the remaining distance is 2.1106356288215886e-227
# after 754, the remaining distance is 1.0553178144107943e-227
# after 755, the remaining distance is 5.276589072053972e-228
# after 756, the remaining distance is 2.638294536026986e-228
# after 757, the remaining distance is 1.319147268013493e-228
# after 758, the remaining distance is 6.595736340067465e-229
# after 759, the remaining distance is 3.2978681700337323e-229
# after 760, the remaining distance is 1.6489340850168661e-229
# after 761, the remaining distance is 8.244670425084331e-230
# after 762, the remaining distance is 4.1223352125421653e-230
# after 763, the remaining distance is 2.0611676062710827e-230
# after 764, the remaining distance is 1.0305838031355413e-230
# after 765, the remaining distance is 5.152919015677707e-231
# after 766, the remaining distance is 2.5764595078388533e-231
# after 767, the remaining distance is 1.2882297539194267e-231
# after 768, the remaining distance is 6.441148769597133e-232
# after 769, the remaining distance is 3.220574384798567e-232
# after 770, the remaining distance is 1.6102871923992833e-232
# after 771, the remaining distance is 8.051435961996417e-233
# after 772, the remaining distance is 4.0257179809982083e-233
# after 773, the remaining distance is 2.0128589904991042e-233
# after 774, the remaining distance is 1.0064294952495521e-233
# after 775, the remaining distance is 5.0321474762477604e-234
# after 776, the remaining distance is 2.5160737381238802e-234
# after 777, the remaining distance is 1.2580368690619401e-234
# after 778, the remaining distance is 6.290184345309701e-235
# after 779, the remaining distance is 3.1450921726548502e-235
# after 780, the remaining distance is 1.5725460863274251e-235
# after 781, the remaining distance is 7.862730431637126e-236
# after 782, the remaining distance is 3.931365215818563e-236
# after 783, the remaining distance is 1.9656826079092814e-236
# after 784, the remaining distance is 9.828413039546407e-237
# after 785, the remaining distance is 4.914206519773204e-237
# after 786, the remaining distance is 2.457103259886602e-237
# after 787, the remaining distance is 1.228551629943301e-237
# after 788, the remaining distance is 6.142758149716505e-238
# after 789, the remaining distance is 3.0713790748582522e-238
# after 790, the remaining distance is 1.5356895374291261e-238
# after 791, the remaining distance is 7.678447687145631e-239
# after 792, the remaining distance is 3.8392238435728152e-239
# after 793, the remaining distance is 1.9196119217864076e-239
# after 794, the remaining distance is 9.598059608932038e-240
# after 795, the remaining distance is 4.799029804466019e-240
# after 796, the remaining distance is 2.3995149022330095e-240
# after 797, the remaining distance is 1.1997574511165048e-240
# after 798, the remaining distance is 5.998787255582524e-241
# after 799, the remaining distance is 2.999393627791262e-241
# after 800, the remaining distance is 1.499696813895631e-241
# after 801, the remaining distance is 7.498484069478155e-242
# after 802, the remaining distance is 3.7492420347390774e-242
# after 803, the remaining distance is 1.8746210173695387e-242
# after 804, the remaining distance is 9.373105086847693e-243
# after 805, the remaining distance is 4.686552543423847e-243
# after 806, the remaining distance is 2.3432762717119234e-243
# after 807, the remaining distance is 1.1716381358559617e-243
# after 808, the remaining distance is 5.858190679279809e-244
# after 809, the remaining distance is 2.9290953396399042e-244
# after 810, the remaining distance is 1.4645476698199521e-244
# after 811, the remaining distance is 7.322738349099761e-245
# after 812, the remaining distance is 3.6613691745498803e-245
# after 813, the remaining distance is 1.8306845872749401e-245
# after 814, the remaining distance is 9.153422936374701e-246
# after 815, the remaining distance is 4.5767114681873503e-246
# after 816, the remaining distance is 2.2883557340936752e-246
# after 817, the remaining distance is 1.1441778670468376e-246
# after 818, the remaining distance is 5.720889335234188e-247
# after 819, the remaining distance is 2.860444667617094e-247
# after 820, the remaining distance is 1.430222333808547e-247
# after 821, the remaining distance is 7.151111669042735e-248
# after 822, the remaining distance is 3.5755558345213674e-248
# after 823, the remaining distance is 1.7877779172606837e-248
# after 824, the remaining distance is 8.938889586303419e-249
# after 825, the remaining distance is 4.4694447931517093e-249
# after 826, the remaining distance is 2.2347223965758547e-249
# after 827, the remaining distance is 1.1173611982879273e-249
# after 828, the remaining distance is 5.586805991439637e-250
# after 829, the remaining distance is 2.7934029957198183e-250
# after 830, the remaining distance is 1.3967014978599092e-250
# after 831, the remaining distance is 6.983507489299546e-251
# after 832, the remaining distance is 3.491753744649773e-251
# after 833, the remaining distance is 1.7458768723248864e-251
# after 834, the remaining distance is 8.729384361624432e-252
# after 835, the remaining distance is 4.364692180812216e-252
# after 836, the remaining distance is 2.182346090406108e-252
# after 837, the remaining distance is 1.091173045203054e-252
# after 838, the remaining distance is 5.45586522601527e-253
# after 839, the remaining distance is 2.727932613007635e-253
# after 840, the remaining distance is 1.3639663065038175e-253
# after 841, the remaining distance is 6.819831532519088e-254
# after 842, the remaining distance is 3.409915766259544e-254
# after 843, the remaining distance is 1.704957883129772e-254
# after 844, the remaining distance is 8.52478941564886e-255
# after 845, the remaining distance is 4.26239470782443e-255
# after 846, the remaining distance is 2.131197353912215e-255
# after 847, the remaining distance is 1.0655986769561075e-255
# after 848, the remaining distance is 5.327993384780537e-256
# after 849, the remaining distance is 2.6639966923902686e-256
# after 850, the remaining distance is 1.3319983461951343e-256
# after 851, the remaining distance is 6.659991730975672e-257
# after 852, the remaining distance is 3.329995865487836e-257
# after 853, the remaining distance is 1.664997932743918e-257
# after 854, the remaining distance is 8.32498966371959e-258
# after 855, the remaining distance is 4.162494831859795e-258
# after 856, the remaining distance is 2.0812474159298974e-258
# after 857, the remaining distance is 1.0406237079649487e-258
# after 858, the remaining distance is 5.2031185398247434e-259
# after 859, the remaining distance is 2.6015592699123717e-259
# after 860, the remaining distance is 1.3007796349561859e-259
# after 861, the remaining distance is 6.503898174780929e-260
# after 862, the remaining distance is 3.2519490873904646e-260
# after 863, the remaining distance is 1.6259745436952323e-260
# after 864, the remaining distance is 8.129872718476162e-261
# after 865, the remaining distance is 4.064936359238081e-261
# after 866, the remaining distance is 2.0324681796190404e-261
# after 867, the remaining distance is 1.0162340898095202e-261
# after 868, the remaining distance is 5.081170449047601e-262
# after 869, the remaining distance is 2.5405852245238005e-262
# after 870, the remaining distance is 1.2702926122619002e-262
# after 871, the remaining distance is 6.351463061309501e-263
# after 872, the remaining distance is 3.1757315306547506e-263
# after 873, the remaining distance is 1.5878657653273753e-263
# after 874, the remaining distance is 7.939328826636877e-264
# after 875, the remaining distance is 3.9696644133184383e-264
# after 876, the remaining distance is 1.9848322066592191e-264
# after 877, the remaining distance is 9.924161033296096e-265
# after 878, the remaining distance is 4.962080516648048e-265
# after 879, the remaining distance is 2.481040258324024e-265
# after 880, the remaining distance is 1.240520129162012e-265
# after 881, the remaining distance is 6.20260064581006e-266
# after 882, the remaining distance is 3.10130032290503e-266
# after 883, the remaining distance is 1.550650161452515e-266
# after 884, the remaining distance is 7.753250807262575e-267
# after 885, the remaining distance is 3.8766254036312874e-267
# after 886, the remaining distance is 1.9383127018156437e-267
# after 887, the remaining distance is 9.691563509078218e-268
# after 888, the remaining distance is 4.845781754539109e-268
# after 889, the remaining distance is 2.4228908772695546e-268
# after 890, the remaining distance is 1.2114454386347773e-268
# after 891, the remaining distance is 6.057227193173887e-269
# after 892, the remaining distance is 3.0286135965869433e-269
# after 893, the remaining distance is 1.5143067982934716e-269
# after 894, the remaining distance is 7.571533991467358e-270
# after 895, the remaining distance is 3.785766995733679e-270
# after 896, the remaining distance is 1.8928834978668395e-270
# after 897, the remaining distance is 9.464417489334198e-271
# after 898, the remaining distance is 4.732208744667099e-271
# after 899, the remaining distance is 2.3661043723335494e-271
# after 900, the remaining distance is 1.1830521861667747e-271
# after 901, the remaining distance is 5.915260930833874e-272
# after 902, the remaining distance is 2.957630465416937e-272
# after 903, the remaining distance is 1.4788152327084684e-272
# after 904, the remaining distance is 7.394076163542342e-273
# after 905, the remaining distance is 3.697038081771171e-273
# after 906, the remaining distance is 1.8485190408855855e-273
# after 907, the remaining distance is 9.242595204427927e-274
# after 908, the remaining distance is 4.621297602213964e-274
# after 909, the remaining distance is 2.310648801106982e-274
# after 910, the remaining distance is 1.155324400553491e-274
# after 911, the remaining distance is 5.776622002767455e-275
# after 912, the remaining distance is 2.8883110013837273e-275
# after 913, the remaining distance is 1.4441555006918637e-275
# after 914, the remaining distance is 7.220777503459318e-276
# after 915, the remaining distance is 3.610388751729659e-276
# after 916, the remaining distance is 1.8051943758648296e-276
# after 917, the remaining distance is 9.025971879324148e-277
# after 918, the remaining distance is 4.512985939662074e-277
# after 919, the remaining distance is 2.256492969831037e-277
# after 920, the remaining distance is 1.1282464849155185e-277
# after 921, the remaining distance is 5.641232424577593e-278
# after 922, the remaining distance is 2.8206162122887962e-278
# after 923, the remaining distance is 1.4103081061443981e-278
# after 924, the remaining distance is 7.051540530721991e-279
# after 925, the remaining distance is 3.5257702653609953e-279
# after 926, the remaining distance is 1.7628851326804976e-279
# after 927, the remaining distance is 8.814425663402488e-280
# after 928, the remaining distance is 4.407212831701244e-280
# after 929, the remaining distance is 2.203606415850622e-280
# after 930, the remaining distance is 1.101803207925311e-280
# after 931, the remaining distance is 5.509016039626555e-281
# after 932, the remaining distance is 2.7545080198132776e-281
# after 933, the remaining distance is 1.3772540099066388e-281
# after 934, the remaining distance is 6.886270049533194e-282
# after 935, the remaining distance is 3.443135024766597e-282
# after 936, the remaining distance is 1.7215675123832985e-282
# after 937, the remaining distance is 8.607837561916492e-283
# after 938, the remaining distance is 4.303918780958246e-283
# after 939, the remaining distance is 2.151959390479123e-283
# after 940, the remaining distance is 1.0759796952395615e-283
# after 941, the remaining distance is 5.379898476197808e-284
# after 942, the remaining distance is 2.689949238098904e-284
# after 943, the remaining distance is 1.344974619049452e-284
# after 944, the remaining distance is 6.72487309524726e-285
# after 945, the remaining distance is 3.36243654762363e-285
# after 946, the remaining distance is 1.681218273811815e-285
# after 947, the remaining distance is 8.406091369059075e-286
# after 948, the remaining distance is 4.2030456845295373e-286
# after 949, the remaining distance is 2.1015228422647686e-286
# after 950, the remaining distance is 1.0507614211323843e-286
# after 951, the remaining distance is 5.253807105661922e-287
# after 952, the remaining distance is 2.626903552830961e-287
# after 953, the remaining distance is 1.3134517764154804e-287
# after 954, the remaining distance is 6.567258882077402e-288
# after 955, the remaining distance is 3.283629441038701e-288
# after 956, the remaining distance is 1.6418147205193505e-288
# after 957, the remaining distance is 8.209073602596753e-289
# after 958, the remaining distance is 4.1045368012983762e-289
# after 959, the remaining distance is 2.0522684006491881e-289
# after 960, the remaining distance is 1.0261342003245941e-289
# after 961, the remaining distance is 5.1306710016229703e-290
# after 962, the remaining distance is 2.5653355008114852e-290
# after 963, the remaining distance is 1.2826677504057426e-290
# after 964, the remaining distance is 6.413338752028713e-291
# after 965, the remaining distance is 3.2066693760143564e-291
# after 966, the remaining distance is 1.6033346880071782e-291
# after 967, the remaining distance is 8.016673440035891e-292
# after 968, the remaining distance is 4.008336720017946e-292
# after 969, the remaining distance is 2.004168360008973e-292
# after 970, the remaining distance is 1.0020841800044864e-292
# after 971, the remaining distance is 5.010420900022432e-293
# after 972, the remaining distance is 2.505210450011216e-293
# after 973, the remaining distance is 1.252605225005608e-293
# after 974, the remaining distance is 6.26302612502804e-294
# after 975, the remaining distance is 3.13151306251402e-294
# after 976, the remaining distance is 1.56575653125701e-294
# after 977, the remaining distance is 7.82878265628505e-295
# after 978, the remaining distance is 3.914391328142525e-295
# after 979, the remaining distance is 1.9571956640712625e-295
# after 980, the remaining distance is 9.785978320356312e-296
# after 981, the remaining distance is 4.892989160178156e-296
# after 982, the remaining distance is 2.446494580089078e-296
# after 983, the remaining distance is 1.223247290044539e-296
# after 984, the remaining distance is 6.116236450222695e-297
# after 985, the remaining distance is 3.0581182251113476e-297
# after 986, the remaining distance is 1.5290591125556738e-297
# after 987, the remaining distance is 7.645295562778369e-298
# after 988, the remaining distance is 3.8226477813891845e-298
# after 989, the remaining distance is 1.9113238906945923e-298
# after 990, the remaining distance is 9.556619453472961e-299
# after 991, the remaining distance is 4.778309726736481e-299
# after 992, the remaining distance is 2.3891548633682403e-299
# after 993, the remaining distance is 1.1945774316841202e-299
# after 994, the remaining distance is 5.972887158420601e-300
# after 995, the remaining distance is 2.9864435792103004e-300
# after 996, the remaining distance is 1.4932217896051502e-300
# after 997, the remaining distance is 7.466108948025751e-301
# after 998, the remaining distance is 3.7330544740128755e-301
# after 999, the remaining distance is 1.8665272370064378e-301
# after 1000, the remaining distance is 9.332636185032189e-302
# after 1001, the remaining distance is 4.6663180925160944e-302
# after 1002, the remaining distance is 2.3331590462580472e-302
# after 1003, the remaining distance is 1.1665795231290236e-302
# after 1004, the remaining distance is 5.832897615645118e-303
# after 1005, the remaining distance is 2.916448807822559e-303
# after 1006, the remaining distance is 1.4582244039112795e-303
# after 1007, the remaining distance is 7.291122019556398e-304
# after 1008, the remaining distance is 3.645561009778199e-304
# after 1009, the remaining distance is 1.8227805048890994e-304
# after 1010, the remaining distance is 9.113902524445497e-305
# after 1011, the remaining distance is 4.5569512622227484e-305
# after 1012, the remaining distance is 2.2784756311113742e-305
# after 1013, the remaining distance is 1.1392378155556871e-305
# after 1014, the remaining distance is 5.696189077778436e-306
# after 1015, the remaining distance is 2.848094538889218e-306
# after 1016, the remaining distance is 1.424047269444609e-306
# after 1017, the remaining distance is 7.120236347223045e-307
# after 1018, the remaining distance is 3.5601181736115222e-307
# after 1019, the remaining distance is 1.7800590868057611e-307
# after 1020, the remaining distance is 8.900295434028806e-308
# after 1021, the remaining distance is 4.450147717014403e-308
# after 1022, the remaining distance is 2.2250738585072014e-308
# after 1023, the remaining distance is 1.1125369292536007e-308
# after 1024, the remaining distance is 5.562684646268003e-309
# after 1025, the remaining distance is 2.781342323134e-309
# after 1026, the remaining distance is 1.390671161567e-309
# after 1027, the remaining distance is 6.953355807835e-310
# after 1028, the remaining distance is 3.4766779039175e-310
# after 1029, the remaining distance is 1.73833895195875e-310
# after 1030, the remaining distance is 8.691694759794e-311
# after 1031, the remaining distance is 4.345847379897e-311
# after 1032, the remaining distance is 2.1729236899484e-311
# after 1033, the remaining distance is 1.086461844974e-311
# after 1034, the remaining distance is 5.43230922487e-312
# after 1035, the remaining distance is 2.716154612436e-312
# after 1036, the remaining distance is 1.35807730622e-312
# after 1037, the remaining distance is 6.7903865311e-313
# after 1038, the remaining distance is 3.39519326554e-313
# after 1039, the remaining distance is 1.69759663277e-313
# after 1040, the remaining distance is 8.487983164e-314
# after 1041, the remaining distance is 4.243991582e-314
# after 1042, the remaining distance is 2.121995791e-314
# after 1043, the remaining distance is 1.0609978955e-314
# after 1044, the remaining distance is 5.304989477e-315
# after 1045, the remaining distance is 2.65249474e-315
# after 1046, the remaining distance is 1.32624737e-315
# after 1047, the remaining distance is 6.63123685e-316
# after 1048, the remaining distance is 3.3156184e-316
# after 1049, the remaining distance is 1.6578092e-316
# after 1050, the remaining distance is 8.289046e-317
# after 1051, the remaining distance is 4.144523e-317
# after 1052, the remaining distance is 2.0722615e-317
# after 1053, the remaining distance is 1.036131e-317
# after 1054, the remaining distance is 5.180654e-318
# after 1055, the remaining distance is 2.590327e-318
# after 1056, the remaining distance is 1.295163e-318
# after 1057, the remaining distance is 6.4758e-319
# after 1058, the remaining distance is 3.2379e-319
# after 1059, the remaining distance is 1.61895e-319
# after 1060, the remaining distance is 8.095e-320
# after 1061, the remaining distance is 4.0474e-320
# after 1062, the remaining distance is 2.0237e-320
# after 1063, the remaining distance is 1.012e-320
# after 1064, the remaining distance is 5.06e-321
# after 1065, the remaining distance is 2.53e-321
# after 1066, the remaining distance is 1.265e-321
# after 1067, the remaining distance is 6.3e-322
# after 1068, the remaining distance is 3.16e-322
# after 1069, the remaining distance is 1.6e-322
# after 1070, the remaining distance is 8e-323
# after 1071, the remaining distance is 4e-323
# after 1072, the remaining distance is 2e-323
# after 1073, the remaining distance is 1e-323
# after 1074, the remaining distance is 5e-324
# after 1075, the remaining distance is 0.0
